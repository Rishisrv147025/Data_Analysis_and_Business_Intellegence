# %% [markdown]
# # **Video Game Dataset Analysis Using Unsupervised Learning**

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
dataset=pd.read_excel('/content/drive/MyDrive/vid_game_sale.xlsx')

# %%
#Checking whether the dataset has been properly imported or not
dataset
# Out:
#       Rank                        Game Title Platform    Year         Genre  \
# 0        1                        Wii Sports      Wii  2006.0        Sports
# 1        2                 Super Mario Bros.      NES  1985.0      Platform
# 2        3                    Mario Kart Wii      Wii  2008.0        Racing
# 3        4                 Wii Sports Resort      Wii  2009.0        Sports
# 4        5                            Tetris       GB  1989.0        Puzzle
# ...    ...                               ...      ...     ...           ...
# 1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0        Action
# 1903  1904              Xenoblade Chronicles      Wii  2010.0  Role-Playing
# 1904  1905                     SingStar Abba      PS3  2008.0          Misc
# 1905  1906    FIFA Soccer World Championship      PS2  2000.0        Sports
# 1906  1907        WWE SmackDown vs. Raw 2011     X360  2010.0      Fighting
#
#                         Publisher  North America  Europe  Japan  \
# 0                        Nintendo          40.43   28.39   3.77
# 1                        Nintendo          29.08    3.58   6.81
# 2                        Nintendo          14.50   12.22   3.63
# 3                        Nintendo          14.82   10.51   3.18
# 4                        Nintendo          23.20    2.26   4.22
# ...                           ...            ...     ...    ...
# 1902   Disney Interactive Studios           0.60    0.22   0.00
# 1903                     Nintendo           0.39    0.22   0.16
# 1904  Sony Computer Entertainment           0.25    0.44   0.00
# 1905              Electronic Arts           0.27    0.21   0.28
# 1906                          THQ           0.42    0.32   0.00
#
#       Rest of World  Global  Review
# 0              8.54   81.12   76.28
# 1              0.77   40.24   91.00
# 2              3.21   33.55   82.07
# 3              3.01   31.52   82.65
# 4              0.58   30.26   88.00
# ...             ...     ...     ...
# 1902           0.01    0.83   55.00
# 1903           0.07    0.83   91.74
# 1904           0.14    0.83   73.00
# 1905           0.07    0.83   73.00
# 1906           0.09    0.83   82.00
#
# [1907 rows x 12 columns]

# %% [markdown]
# # Data Cleaning

# %%
#checking if there is any missing values in the dataset
dataset.isnull().sum()
# Out:
# Rank              0
# Game Title        0
# Platform          0
# Year             29
# Genre             0
# Publisher         2
# North America     0
# Europe            0
# Japan             0
# Rest of World     0
# Global            0
# Review            0
# dtype: int64

# %%
#importing the imputer library to fill the missing values
from sklearn.impute import SimpleImputer

# %%
#Creating the object for imputer library
num_imputer=SimpleImputer(strategy='mean')
cat_imputer=SimpleImputer(strategy='most_frequent')

# %%
#Filling the dataset using imputer
dataset['Year']=num_imputer.fit_transform(dataset[['Year']])

# %%
#Using the imputer to fill the publisher data's in the dataset
dataset['Publisher']=cat_imputer.fit_transform(dataset['Publisher'].values.reshape(-1,1))[:,0]

# %%
#After applying the imputer function checking if there is any missing values in the dataset
dataset.isnull().sum()
# Out:
# Rank             0
# Game Title       0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# Review           0
# dtype: int64

# %%
#Converting the dataset from object to integers.
dataset['Year']=dataset['Year'].astype(int)

# %%
#After conversion checking whether it has been properly converted or not
dataset['Year'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # Uni-Varite Analysis

# %%
#Checking for the number of values in the rank column.
dataset['Rank'].value_counts()
# Out:
# Rank
# 1       1
# 1268    1
# 1280    1
# 1279    1
# 1278    1
#        ..
# 632     1
# 631     1
# 630     1
# 629     1
# 1907    1
# Name: count, Length: 1907, dtype: int64

# %%
#Visualizing the North america values.
dataset['North America'].value_counts().plot(kind='hist',figsize=(14,7))
plt.suptitle('Hist of North America',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Hist of North America')

# %%
#Visualizing the Europe data in the dataset.
plt.figure(figsize=(14,5))
sns.histplot(dataset,x='Europe')
plt.suptitle('Countplot of Europe',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Countplot of Europe')

# %%
#Visualizing the japan dataset using boxplot
plt.figure(figsize=(14,5))
sns.boxplot(dataset,x='Japan')
plt.suptitle('Comapring the values of Japan in the dataset',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Comapring the values of Japan in the dataset')

# %%
#Visualizing the Europe data in the dataset.
plt.figure(figsize=(14,5))
sns.histplot(dataset,x='Global')
plt.suptitle('Countplot of Global',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Countplot of Global')

# %%
#Visualizing the North america values.
dataset['Rest of World'].value_counts().plot(kind='hist',figsize=(14,7))
plt.suptitle('Hist of Rest of World',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Hist of Rest of World')

# %% [markdown]
# # Bi-Variate Analysis

# %%
#Comparing the Rank and Reviews in the dataset
plt.figure(figsize=(14,7))
sns.lineplot(dataset,x='Rank',y='Review')
plt.suptitle('lineplot of Rank Vs Review',fontsize=20)
# Out:
# Text(0.5, 0.98, 'lineplot of Rank Vs Review')

# %%
#comparing the dataset between the Rank Vs North America.
plt.figure(figsize=(14,7))
sns.scatterplot(dataset,x='Rank',y='North America')
plt.suptitle('Scatterplot of Rank Vs North America',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scatterplot of Rank Vs North America')

# %%
#comparing the dataset between the Rank Vs North America.
plt.figure(figsize=(14,7))
sns.scatterplot(dataset,x='Rank',y='Japan')
plt.suptitle('Scatterplot of Rank Vs Japan',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scatterplot of Rank Vs Japan')

# %%
#comparing the dataset between the Rank Vs North America.
plt.figure(figsize=(14,7))
sns.scatterplot(dataset,x='Rank',y='Rest of World')
plt.suptitle('Scatterplot of Rank Vs ROW',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scatterplot of Rank Vs ROW')

# %% [markdown]
# # Correlation Analysis

# %%
#Getting only the numerical values in a dataset.
num_data=['Rank','Year','North America','Europe','Japan','Rest of World','Global','Review']

# %%
#Getting the correlation of the numeric dataset using the heatmap.
plt.figure(figsize=(14,5))
sns.heatmap(dataset[num_data].corr(),annot=True,cmap='coolwarm')
plt.suptitle('Correlation of the dataset',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Correlation of the dataset')

# %% [markdown]
# # Grouping & Aggregation

# %%
#Using the plotly library.
import plotly.express as px

# %%
# Group by Genre and sum up the Global sales
genre_sales = dataset.groupby('Genre')['Global'].sum().reset_index()
genre_sales
# Out:
#            Genre  Global
# 0         Action  637.27
# 1      Adventure  239.45
# 2       Fighting  249.00
# 3           Misc  426.12
# 4       Platform  595.24
# 5         Puzzle  108.65
# 6         Racing  451.80
# 7   Role-Playing  496.20
# 8        Shooter  557.20
# 9     Simulation  205.14
# 10        Sports  703.11
# 11      Strategy   77.80

# %%
# Create a bar chart showing global sales by Genre
fig = px.bar(genre_sales, x='Genre', y='Global', title='Global Sales by Genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="578bdb3c-d300-4a7b-8d92-bef370ea94a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("578bdb3c-d300-4a7b-8d92-bef370ea94a8")) {                    Plotly.newPlot(                        "578bdb3c-d300-4a7b-8d92-bef370ea94a8",                        [{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eGlobal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Action","Adventure","Fighting","Misc","Platform","Puzzle","Racing","Role-Playing","Shooter","Simulation","Sports","Strategy"],"xaxis":"x","y":[637.27,239.45,249.0,426.12,595.24,108.65,451.8,496.2,557.2,205.14,703.11,77.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"p ...

# %%
# Group by Platform and calculate the average Review score
platform_reviews = dataset.groupby('Platform')['Review'].mean().reset_index()
platform_reviews
# Out:
#    Platform     Review
# 0       3DS  81.246000
# 1        DC  91.545000
# 2        DS  73.234430
# 3        GB  78.637917
# 4       GBA  75.041200
# 5        GC  80.737818
# 6       GEN  86.090909
# 7       N64  81.261404
# 8       NES  76.245000
# 9        PC  84.619437
# 10       PS  76.603812
# 11      PS2  79.499543
# 12      PS3  82.476584
# 13      PSP  79.961111
# 14      PSV  84.000000
# 15      SAT  87.946667
# 16      SCD  70.000000
# 17     SNES  86.115366
# 18      Wii  72.443230
# 19     WiiU  81.340000
# 20     X360  81.718630
# 21       XB  83.573333

# %%
# Create a bar chart showing average review scores by Platform
fig = px.bar(platform_reviews, x='Platform', y='Review', title='Average Review Score by Platform')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0d3c535f-1f7e-48d5-be65-82e6ba2305e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d3c535f-1f7e-48d5-be65-82e6ba2305e9")) {                    Plotly.newPlot(                        "0d3c535f-1f7e-48d5-be65-82e6ba2305e9",                        [{"alignmentgroup":"True","hovertemplate":"Platform=%{x}\u003cbr\u003eReview=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["3DS","DC","DS","GB","GBA","GC","GEN","N64","NES","PC","PS","PS2","PS3","PSP","PSV","SAT","SCD","SNES","Wii","WiiU","X360","XB"],"xaxis":"x","y":[81.24600000000001,91.545,73.23442953020134,78.63791666666667,75.0412,80.73781818181818,86.0909090909091,81.26140350877192,76.24499999999999,84.61943661971831,76.60381165919283,79.49954301075269,82.47658415841585,79.96111111111111,84.0,87.94666666666666,70.0,86.11536585365853,72.4432298136646,81.34,81.7186301369863,83.57333333333332],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line": ...

# %%
# Group by Genre and sum Global sales
genre_sales = dataset.groupby('Genre')['Global'].sum().reset_index()
genre_sales = genre_sales.sort_values(by='Global', ascending=False)
genre_sales
# Out:
#            Genre  Global
# 10        Sports  703.11
# 0         Action  637.27
# 4       Platform  595.24
# 8        Shooter  557.20
# 7   Role-Playing  496.20
# 6         Racing  451.80
# 3           Misc  426.12
# 2       Fighting  249.00
# 1      Adventure  239.45
# 9     Simulation  205.14
# 5         Puzzle  108.65
# 11      Strategy   77.80

# %%
plt.figure(figsize=(14, 5))
sns.barplot(x='Global', y='Genre', data=genre_sales)
plt.suptitle('Total Global Sales by Genre',fontsize=20)
plt.xlabel('Global Sales (millions)')
plt.ylabel('Genre')
# Out:
# Text(0, 0.5, 'Genre')

# %%
platform_year_sales = dataset.groupby(['Platform', 'Year'])['Global'].sum().unstack()
platform_year_sales
# Out:
# Year       1983   1984   1985   1986   1987   1988   1989   1990   1991  \
# Platform
# 3DS         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# DC          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# DS          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# GB          NaN    NaN    NaN    NaN    NaN   1.43  60.10   4.56   2.90
# GBA         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# GC          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# GEN         NaN    NaN    NaN    NaN    NaN    NaN    NaN   2.60   4.34
# N64         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NES       10.96  45.66  49.57  27.17  17.06  40.76   2.77  13.16   2.98
# PC          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PS          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PS2         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PS3         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PSP         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PSV         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# SAT         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# SCD         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# SNES        NaN    NaN    NaN    NaN    NaN    NaN    NaN  26.16  11.19
# Wii         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# WiiU        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# X360        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# XB          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# Year       1992  ...    2003    2004    2005    2006    2007    2008    2009  \
# Platform         ...
# 3DS         NaN  ...    1.18     NaN     NaN     NaN     NaN     NaN     NaN
# DC          NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# DS          NaN  ...     NaN   12.21  110.93   86.27   81.98   64.07   50.73
# GB        25.25  ...    1.03     NaN     NaN     NaN     NaN     NaN     NaN
# GBA         NaN  ...   32.39   36.26    7.13     NaN    1.21     NaN     NaN
# GC          NaN  ...   27.91   13.77   11.06    3.48     NaN     NaN     NaN
# GEN       12.41  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# N64         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NES        1.30  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PC         6.94  ...   10.41   12.86    3.78     NaN    6.18    6.95    3.96
# PS          NaN  ...    3.73     NaN     NaN     NaN     NaN     NaN     NaN
# PS2         NaN  ...  143.20  156.44  100.40   63.50   38.42   16.75    6.44
# PS3         NaN  ...    2.42     NaN     NaN   14.41   49.25   80.36   81.20
# PSP         NaN  ...    1.97    5.25   24.43   27.42   19.93   16.81    9.56
# PSV         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# SAT         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# SCD         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# SNES      25.57  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Wii         NaN  ...   10.08     NaN     NaN  126.57  111.41  105.00  128.48
# WiiU        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# X360        NaN  ...    2.40     NaN    2.96   32.98   63.59   95.98   76.76
# XB          NaN  ...   26.00   34.22   15.45    1.02     NaN     NaN     NaN
#
# Year        2010   2011   2012
# Platform
# 3DS          NaN  25.69  11.06
# DC           NaN    NaN    NaN
# DS         35.29   5.93   6.38
# GB           NaN    NaN    NaN
# GBA          NaN    NaN    NaN
# GC           NaN    NaN    NaN
# GEN          NaN    NaN    NaN
# N64          NaN    NaN    NaN
# NES          NaN    NaN    NaN
# PC         12.02  11.74   6.93
# PS           NaN    NaN    NaN
# PS2          NaN    NaN    NaN
# PS3        88.02  86.52  44.16
# PSP         4.85    NaN    NaN
# PSV          NaN   0.93    NaN
# SAT          NaN    NaN    NaN
# SCD          NaN    NaN    NaN
# SNES         NaN    NaN    NaN
# Wii        71.74  27.20   9.68
# WiiU         NaN    NaN   3.36
# X360      122.19  93.00  55.84
# XB           NaN    NaN    NaN
#
# [22 rows x 30 columns]

# %%
platform_year_sales.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Total Global Sales by Platform and Year')
plt.xlabel('Year')
plt.ylabel('Global Sales (millions)')
plt.legend(title='Platform')

# %%
# Group by Genre and Platform, summing Global sales
genre_platform_sales = dataset.groupby(['Genre', 'Platform'])['Global'].sum().unstack(fill_value=0)
genre_platform_sales
# Out:
# Platform        3DS    DC      DS     GB    GBA     GC    GEN    N64    NES  \
# Genre
# Action         4.38  1.14   19.25   1.73  13.06  14.14   2.60   7.89   9.14
# Adventure      4.06  1.18   41.75  11.59  13.58   8.06   0.00  10.96  13.62
# Fighting       0.90  0.00    0.00   0.00   1.08   9.61   5.67  15.81   6.47
# Misc           0.00  0.00   89.63   8.50   8.94  10.97   0.00   8.56   2.14
# Platform      13.87  2.42   62.32  64.73  49.61  16.98  15.36  30.62  87.99
# Puzzle         0.00  0.00   18.15  44.77   7.05   2.98   0.00   1.04  16.13
# Racing         7.71  1.81   24.57   4.55   8.63  12.83   0.00  25.49   7.64
# Role-Playing   2.32  0.00  103.01  48.56  51.98   8.63   0.00   1.38  15.30
# Shooter        0.00  0.00    1.00   1.20   0.00   5.23   0.00  14.42  30.85
# Simulation     3.78  0.00   78.48   1.45   1.33   5.05   0.00   8.75   0.00
# Sports         0.91  2.29   11.68   4.63   1.18   5.82   3.16  13.00  23.86
# Strategy       0.00  0.00    3.95   7.30   3.93   2.83   0.00   9.55   0.00
#
# Platform         PC  ...     PS3    PSP   PSV   SAT  SCD   SNES     Wii  WiiU  \
# Genre                ...
# Action         2.92  ...  122.67  23.14  0.93  0.00  0.0   2.58   26.21  3.36
# Adventure     14.70  ...   19.93   4.15  0.00  0.00  0.0   6.03   23.27  0.00
# Fighting       0.00  ...   27.62   5.90  0.00  3.00  0.0  19.06   14.52  0.00
# Misc           8.87  ...   13.83   2.40  0.00  0.00  0.0   2.75  137.43  0.00
# Platform       0.00  ...   16.10  10.89  0.00  0.00  1.5  61.80   75.76  0.00
# Puzzle         0.00  ...    0.00   1.10  0.00  0.00  0.0   1.70    6.92  0.00
# Racing         0.00  ...   42.87  18.93  0.00  1.16  0.0  12.51   38.65  0.00
# Role-Playing  38.04  ...   29.00  17.17  0.00  0.00  0.0  18.26    4.44  0.00
# Shooter       21.72  ...  115.75  10.61  0.00  0.00  0.0   4.64   19.33  0.00
# Simulation    46.12  ...    3.07   2.22  0.00  0.00  0.0   3.12   12.67  0.00
# Sports         3.67  ...   55.50  12.85  0.00  0.00  0.0   2.40  230.96  0.00
# Strategy      39.18  ...    0.00   0.86  0.00  0.00  0.0   0.00    0.00  0.00
#
# Platform        X360     XB
# Genre
# Action         95.13  22.10
# Adventure      20.40   2.05
# Fighting       20.53   3.73
# Misc           49.74   3.03
# Platform        6.69   2.13
# Puzzle          0.00   0.00
# Racing         38.24  13.58
# Role-Playing   46.21   9.98
# Shooter       198.56  35.44
# Simulation      5.04   2.00
# Sports         61.98  16.09
# Strategy        3.18   0.00
#
# [12 rows x 22 columns]

# %%
genre_platform_sales.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Total Global Sales by Genre and Platform')
plt.xlabel('Genre')
plt.ylabel('Global Sales (millions)')
plt.legend(title='Platform')

# %%
# Group by Year and sum sales across regions
yearly_region_sales = dataset.groupby('Year')[['North America', 'Europe', 'Japan', 'Rest of World']].sum().reset_index()
yearly_region_sales
# Out:
#     Year  North America  Europe  Japan  Rest of World
# 0   1983           2.32    0.46   8.10           0.08
# 1   1984          32.15    1.85  11.00           0.65
# 2   1985          32.09    4.45  12.13           0.90
# 3   1986          10.59    2.60  13.58           0.40
# 4   1987           5.28    1.18  10.42           0.18
# 5   1988          21.49    6.26  13.55           0.90
# 6   1989          39.31    7.33  14.85           1.37
# 7   1990          23.59    7.44  14.04           1.39
# 8   1991          10.87    3.67   6.25           0.62
# 9   1992          36.22   12.76  20.65           1.84
# 10  1993          13.47    4.40  10.63           0.86
# 11  1994          31.66   13.94  11.09           2.21
# 12  1995          19.85   11.58  16.16           1.61
# 13  1996          58.38   27.93  20.96           4.61
# 14  1997          66.51   29.77  19.28           5.23
# 15  1998          95.36   48.30  25.91           7.01
# 16  1999          92.63   46.68  30.21           6.65
# 17  2000          78.04   34.64  23.57           7.23
# 18  2001         125.41   67.33  25.89          16.09
# 19  2002         134.39   72.84  21.32          19.66
# 20  2003         142.12   76.97  21.81          22.02
# 21  2004         140.77   80.56  26.68          23.09
# 22  2005         128.02   85.05  35.35          27.66
# 23  2006         168.42  104.81  42.94          39.44
# 24  2007         174.15  127.68  29.29          40.79
# 25  2008         189.66  124.07  30.71          41.51
# 26  2009         170.66  111.22  37.08          38.17
# 27  2010         168.80  103.60  24.78          36.98
# 28  2011         122.96   84.58  13.97          29.42
# 29  2012          65.34   43.68  13.26          15.17

# %%
# Create a line plot for regional sales by year
fig = px.line(yearly_region_sales, x='Year', y=yearly_region_sales.columns[1:],
              title='Regional Sales by Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="76b669a3-7cc2-4124-b459-edf0eb8080d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76b669a3-7cc2-4124-b459-edf0eb8080d2")) {                    Plotly.newPlot(                        "76b669a3-7cc2-4124-b459-edf0eb8080d2",                        [{"hovertemplate":"variable=North America\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North America","orientation":"v","showlegend":true,"x":[1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],"xaxis":"x","y":[2.3200000000000003,32.15,32.089999999999996,10.59,5.279999999999999,21.49,39.31,23.59,10.87,36.22,13.47,31.66,19.85,58.38,66.51,95.36,92.63,78.04,125.41,134.39,142.12,140.77,128.02,168.42,174.15,189.66,170.66,168.8,122.96000000000001,65.34],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Europe\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"x":[1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],"xaxis":"x","y":[0.46,1.85,4.45,2.6,1.18,6.26,7.33,7.44,3.67,12.76,4.4,13.94,11.58,27.93,29.77,48.3,46.68,34.64,67.33,72.84,76.97,80.56,85.05,104.81,127.68,124.07000000000001,111.22,103.6,84.58,43.68],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Japan\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Japan","orientation":"v","showlegend":true,"x":[1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],"xaxis":"x","y":[8.1,11.0,12.129999999999999,13.58,10.42,13.55,14.85,14.04,6.25,20.65,10.63,11.09,16.16,20.96,19.28,25.91,30.21,23.57,25.89,21.32,21.81,26.68,35.35,42.94,29.29,30.71,37.08,24.78,13.969999999999999,13.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Rest of World\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rest of World","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rest of World","orientation":"v","showlegend":true,"x":[1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012],"xaxis":"x","y":[0.08,0.65,0.9,0.4,0.18,0.9,1.3699999999999999,1.3900000000000001,0.62,1.84,0.86,2.21,1.61,4.61,5.23,7.01,6.65,7.23,16.09,19.66,22.02,23.09,27.66,39.44,40.79,41.51,38.17,36.980000000000004,29.42,15.17],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %%
# Aggregate sales by region
region_sales = dataset[['North America', 'Europe', 'Japan', 'Rest of World']].sum().reset_index()

# Rename columns for readability
region_sales.columns = ['Region', 'Sales']

# For visualization, we will map regions to countries (ISO 3166-1 alpha-3 codes)
region_codes = {
    'North America': 'USA',  # Example: You could aggregate USA, Canada, Mexico into this category
    'Europe': 'EUU',  # Placeholder for Europe; you can split or map specific countries if needed
    'Japan': 'JPN',   # Japan code
    'Rest of World': 'ROW'  # You could specify additional regions or leave this as "Rest of World"
}

# Map the region names to their respective country codes
region_sales['Country_Code'] = region_sales['Region'].map(region_codes)

# Create the choropleth map
fig = px.choropleth(region_sales,
                    locations='Country_Code',
                    color='Sales',
                    hover_name='Region',
                    color_continuous_scale='Viridis',
                    title="Regional Sales in Video Games")

# Show the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e82c654b-c772-4283-9dea-2737edec1bed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e82c654b-c772-4283-9dea-2737edec1bed")) {                    Plotly.newPlot(                        "e82c654b-c772-4283-9dea-2737edec1bed",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry_Code=%{location}\u003cbr\u003eSales=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["North America","Europe","Japan","Rest of World"],"locations":["USA","EUU","JPN","ROW"],"name":"","z":[2400.51,1347.6299999999999,605.46,393.74],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %% [markdown]
# # Predicting the dataset using Un-supervised Algorithm

# %%
#importing the sklearn library for performing the machine learning libraries.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans, MiniBatchKMeans, AgglomerativeClustering, SpectralClustering

# %%
#Since we are going to perform only unsupervised only object data type is preprocessed
lab=LabelEncoder()

# %%
#Preprocessing only the object column in the dataset.
dataset['Game Title']=lab.fit_transform(dataset['Game Title'])
dataset['Platform']=lab.fit_transform(dataset['Platform'])
dataset['Genre']=lab.fit_transform(dataset['Genre'])
dataset['Publisher']=lab.fit_transform(dataset['Publisher'])

# %%
#Looking for the dataset once it is preprocessed
dataset
# Out:
#       Rank  Game Title  Platform  Year  Genre  Publisher  North America  \
# 0        1        1456        18  2006     10         53          40.43
# 1        2        1193         8  1985      4         53          29.08
# 2        3         630        18  2008      6         53          14.50
# 3        4        1457        18  2009     10         53          14.82
# 4        5        1254         3  1989      5         53          23.20
# ...    ...         ...       ...   ...    ...        ...            ...
# 1902  1903         574         4  2004      0         22           0.60
# 1903  1904        1483        18  2010      7         53           0.39
# 1904  1905        1066        12  2008      3         69           0.25
# 1905  1906         311        11  2000     10         24           0.27
# 1906  1907        1418        20  2010      2         77           0.42
#
#       Europe  Japan  Rest of World  Global  Review
# 0      28.39   3.77           8.54   81.12   76.28
# 1       3.58   6.81           0.77   40.24   91.00
# 2      12.22   3.63           3.21   33.55   82.07
# 3      10.51   3.18           3.01   31.52   82.65
# 4       2.26   4.22           0.58   30.26   88.00
# ...      ...    ...            ...     ...     ...
# 1902    0.22   0.00           0.01    0.83   55.00
# 1903    0.22   0.16           0.07    0.83   91.74
# 1904    0.44   0.00           0.14    0.83   73.00
# 1905    0.21   0.28           0.07    0.83   73.00
# 1906    0.32   0.00           0.09    0.83   82.00
#
# [1907 rows x 12 columns]

# %%
#Creating the KMeans un-supervised model
model=KMeans()

# %%
#Fitting the dataset to the model.
model.fit(dataset)
# Out:
# KMeans()

# %%
#Checking for the clustered label's in the k-means
model.labels_
# Out:
# array([3, 3, 7, ..., 4, 6, 4], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[7.22116000e+02, 7.42328000e+02, 1.17240000e+01, 2.00360800e+03,
#         5.88000000e+00, 4.43240000e+01, 1.11916000e+00, 4.45040000e-01,
#         2.42200000e-01, 1.55440000e-01, 1.96192000e+00, 8.02116800e+01],
#        [1.55620319e+03, 7.25446215e+02, 1.09601594e+01, 2.00433466e+03,
#         6.16334661e+00, 4.56055777e+01, 5.56892430e-01, 2.74661355e-01,
#         1.16135458e-01, 8.59760956e-02, 1.03362550e+00, 7.73029880e+01],
#        [9.44235537e+02, 1.22522727e+03, 1.09545455e+01, 2.00268595e+03,
#         5.06611570e+00, 4.67561983e+01, 8.41363636e-01, 4.52809917e-01,
#         1.55826446e-01, 1.24876033e-01, 1.57450413e+00, 7.78434711e+01],
#        [2.85711382e+02, 1.20371951e+03, 9.82113821e+00, 2.00195122e+03,
#         4.63008130e+00, 4.87601626e+01, 2.84731707e+00, 1.61406504e+00,
#         8.57601626e-01, 4.01829268e-01, 5.72048780e+00, 8.42167886e+01],
#        [1.57375909e+03, 1.25617727e+03, 1.20045455e+01, 2.00449091e+03,
#         5.10909091e+00, 4.99681818e+01, 5.16000000e-01, 3.12909091e-01,
#         1.02727273e-01, 9.06818182e-02, 1.02168182e+00, 7.51785000e+01],
#        [1.02856652e+03, 2.81579399e+02, 1.17038627e+01, 2.00427897e+03,
#         4.97854077e+00, 4.17596567e+01, 7.09399142e-01, 4.22060086e-01,
#         2.05879828e-01, 1.33991416e-01, 1.47111588e+00, 7.62970386e+01],
#        [1.62894857e+03, 2.13874286e+02, 1.19657143e+01, 2.00459429e+03,
#         5.34285714e+00, 3.99828571e+01, 4.33714286e-01, 3.09485714e-01,
#         1.49771429e-01, 9.37142857e-02, 9.86628571e-01, 7.61176000e+01],
#        [2.70355172e+02, 3.32517241e+02, 1.22793103e+01, 2.00431724e+03,
#         5.28620690e+00, 4.72275862e+01, 2.49027586e+00, 1.51534483e+00,
#         5.87241379e-01, 4.71241379e-01, 5.06410345e+00, 8.30305172e+01]])

# %%
model_1=MiniBatchKMeans()

# %%
#Importing the 2nd model
model_1.fit(dataset)
# Out:
# MiniBatchKMeans()

# %%
#checking for the clustered lables
model_1.labels_
# Out:
# array([5, 5, 2, ..., 6, 7, 6], dtype=int32)

# %%
model_1.cluster_centers_
# Out:
# array([[9.52388578e+02, 1.14390929e+03, 1.11548152e+01, 2.00281439e+03,
#         5.35190370e+00, 4.63633819e+01, 8.34316909e-01, 4.44826428e-01,
#         1.56385778e-01, 1.26201008e-01, 1.56157055e+00, 7.83085946e+01],
#        [9.27987070e+02, 3.46433302e+02, 1.13711763e+01, 2.00393504e+03,
#         5.11699779e+00, 4.40258594e+01, 8.15159256e-01, 4.10135604e-01,
#         2.34695680e-01, 1.33667613e-01, 1.59323557e+00, 7.75329171e+01],
#        [3.21964602e+02, 3.91039710e+02, 1.23737236e+01, 2.00432562e+03,
#         5.36192421e+00, 4.75153165e+01, 2.21529158e+00, 1.30067847e+00,
#         5.35144089e-01, 4.12977082e-01, 4.46402088e+00, 8.26979737e+01],
#        [1.73533214e+03, 7.17268568e+02, 1.15614973e+01, 2.00506714e+03,
#         6.21746881e+00, 4.74515746e+01, 5.03963161e-01, 2.52168746e-01,
#         9.12477718e-02, 7.55139632e-02, 9.22305407e-01, 7.53923232e+01],
#        [1.33460476e+03, 6.82379375e+02, 1.06514232e+01, 2.00384228e+03,
#         5.64769015e+00, 4.19612692e+01, 6.54153056e-01, 3.04167056e-01,
#         1.22846477e-01, 9.77088194e-02, 1.17963602e+00, 7.77781801e+01],
#        [3.50902111e+02, 1.16933430e+03, 1.02411609e+01, 2.00241979e+03,
#         4.58759894e+00, 4.75894459e+01, 2.43903694e+00, 1.41370712e+00,
#         7.06791557e-01, 3.57667546e-01, 4.91689710e+00, 8.33673430e+01],
#        [1.57995331e+03, 1.26549521e+03, 1.18659218e+01, 2.00447127e+03,
#         5.07781325e+00, 5.03946528e+01, 5.05953711e-01, 3.17729449e-01,
#         1.01735834e-01, 9.23703113e-02, 1.01709497e+00, 7.51589186e+01],
#        [1.59026404e+03, 1.93510526e+02, 1.18464912e+01, 2.00454254e+03,
#         5.33157895e+00, 3.99543860e+01, 4.59127193e-01, 3.03758772e-01,
#         1.54491228e-01, 9.45000000e-02, 1.01164912e+00, 7.66196096e+01]])

# %%
#Importing the 3rd model
model_2=AgglomerativeClustering()

# %%
#Fitting the dataset
model_2.fit(dataset)
# Out:
# AgglomerativeClustering()

# %%
#Getting the clustered values.
model_2.labels_
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
#Inserting the clustered values of each model to the dataset.
dataset['kmeans']=model.labels_
dataset['minibatchkmeans']=model_1.labels_
dataset['agglo']=model_2.labels_

# %%
#Viewing the dataset
dataset
# Out:
#       Rank  Game Title  Platform  Year  Genre  Publisher  North America  \
# 0        1        1456        18  2006     10         53          40.43
# 1        2        1193         8  1985      4         53          29.08
# 2        3         630        18  2008      6         53          14.50
# 3        4        1457        18  2009     10         53          14.82
# 4        5        1254         3  1989      5         53          23.20
# ...    ...         ...       ...   ...    ...        ...            ...
# 1902  1903         574         4  2004      0         22           0.60
# 1903  1904        1483        18  2010      7         53           0.39
# 1904  1905        1066        12  2008      3         69           0.25
# 1905  1906         311        11  2000     10         24           0.27
# 1906  1907        1418        20  2010      2         77           0.42
#
#       Europe  Japan  Rest of World  Global  Review  kmeans  minibatchkmeans  \
# 0      28.39   3.77           8.54   81.12   76.28       3                5
# 1       3.58   6.81           0.77   40.24   91.00       3                5
# 2      12.22   3.63           3.21   33.55   82.07       7                2
# 3      10.51   3.18           3.01   31.52   82.65       3                5
# 4       2.26   4.22           0.58   30.26   88.00       3                5
# ...      ...    ...            ...     ...     ...     ...              ...
# 1902    0.22   0.00           0.01    0.83   55.00       1                3
# 1903    0.22   0.16           0.07    0.83   91.74       4                6
# 1904    0.44   0.00           0.14    0.83   73.00       4                6
# 1905    0.21   0.28           0.07    0.83   73.00       6                7
# 1906    0.32   0.00           0.09    0.83   82.00       4                6
#
#       agglo
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1902      1
# 1903      1
# 1904      1
# 1905      1
# 1906      1
#
# [1907 rows x 15 columns]

# %% [markdown]
# # Visualizing the Clustered value.

# %%
#Comparing the clustered data with the Global Vs Review data's
plt.figure(figsize=(14,7))
sns.scatterplot(data=dataset,x='Global',y='Review',hue='kmeans',palette="viridis")
plt.suptitle('Comparing the clustered data with the Global Vs Review data using KMeans',fontsize=15)
# Out:
# Text(0.5, 0.98, 'Comparing the clustered data with the Global Vs Review data using KMeans')

# %%
#Comparing the clustered data with the Global Vs Review data's
plt.figure(figsize=(14,7))
sns.scatterplot(data=dataset,x='Global',y='Review',hue='minibatchkmeans',palette="viridis")
plt.suptitle('Comparing the clustered data with the Global Vs Review data using MiniKBatch',fontsize=15)
# Out:
# Text(0.5, 0.98, 'Comparing the clustered data with the Global Vs Review data using MiniKBatch')

# %%
#Comparing the clustered data with the Global Vs Review data's
plt.figure(figsize=(14,7))
sns.scatterplot(data=dataset,x='Global',y='Review',hue='agglo',palette="viridis")
plt.suptitle('Comparing the clustered data with the Global Vs Review data using Aggloramative_Clustering',fontsize=15)
# Out:
# Text(0.5, 0.98, 'Comparing the clustered data with the Global Vs Review data using Aggloramative_Clustering')

# %% [markdown]
# ###**-------- THE END ----------**
